# %% [markdown]
# <a href="https://colab.research.google.com/github/shivckr/Python-Projects-/blob/master/EDA_on_Haberman's_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages 
import pandas as pd                                     # used in data manipulation
import seaborn as sns                                   # used in data visulaization
import matplotlib as plt                                # used in data visualization
# %matplotlib inline

# %%
#data url
data_url = "https://raw.githubusercontent.com/shivckr/border/master/haberman.csv"

# %% [markdown]
# Attribute Information:
#
# Age of patient at time of operation (numerical)
# Patient's year of operation (year - 1900, numerical)
# Number of positive axillary nodes detected (numerical)
# Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year

# %%
#read data
data = pd.read_csv(data_url)
#data shape
data.shape
# Out:
# (305, 4)

# %%
#data head
data.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
#add column header 
data.columns = ['Age','op_Year','axil_nodes','Surv_status']
#data statistics
data.describe()
# Out:
#               Age     op_Year  axil_nodes  Surv_status
# count  305.000000  305.000000  305.000000   305.000000
# mean    52.531148   62.849180    4.036066     1.265574
# std     10.744024    3.254078    7.199370     0.442364
# min     30.000000   58.000000    0.000000     1.000000
# 25%     44.000000   60.000000    0.000000     1.000000
# 50%     52.000000   63.000000    1.000000     1.000000
# 75%     61.000000   66.000000    4.000000     2.000000
# max     83.000000   69.000000   52.000000     2.000000

# %% [markdown]
# Obsevations:
# 1.No missing values
# 2.Age column has almost uniform distribution (sd << mean)
# 3.Following possibilities for column 'axil_nodes'(because sd > mean )
#   1. Nothing. No significant meaning. Just numbers to quantify information.
#   2. There is no/poor precision amongst the sample or data set(s). This means there is a significant distance between the highest and lowest values.
#   3. There is an outlier amongst the data set. This might also imply random errors and can suggest you discard a particular sample/data or redo the analysis (the source of the data obtained).
#   4. You are out of statistical confidence (but this one depends on what we want as alpha).
#   5. Your data is skewed. You may need to normalize your data (or not, it depends on what you are doing).
#   6. There is a wide range of variation amongst the data/sample sets. The data set is not from the same source (As a good thing).
#   7. The standard deviation may not be the best tool to explain the variation of the data-sets. Look at the standard error of mean or the covariance.
#   8. The mean may not be the best measure of accuracy or central tendency. Look at the median or the mode.
#   source : https://www.researchgate.net/post/Can_Standard_Deviation_SD_be_greater_than_MEAN

# %%
sns.countplot(x='Surv_status',data=data)

# %% [markdown]
# Obsevations:
# 1. people who lived > 5 years post surgery
# 2. people who  lived < 5 years post surgery

# %% [markdown]
# #Univariate analysis on Numerical data
# e.g. pdf, cdf,histogram, Boxplot, voilinplot
#
# Numerical data are values that we can perform mathematical operations on. They are further broken down into continuous and discrete data types.
# Discreet variables have to be an integer. An example is number of Super Heroes.
# Continuous can be any value. Examples here include height and weight.
# Numerical data can be visualized with a histogram.
# Histograms are a great first analysis of continuous data.
# Four main aspects to consider here are shape, center, spread, and outliers.
# Shape is the overall appearance of the histogram. It can be symmetric, skewed, uniform, or have multiple peaks.
# Center refers to the mean or median.
# Spread refers to the range or how far the data reaches.
# Outliers are data points that fall far from the bulk of the data.
#
# Source: https://towardsdatascience.com/exploring-univariate-data-e7e2dc8fde80

# %%
sns.set();
sns.distplot(data.Age, kde=True,)

# %% [markdown]
# Age  has almost uniform distribution
# Mean Age is around 50

# %% [markdown]
# # Bi-variate analysis
# e.g. pairplot, scatter plot

# %%
sns.pairplot(data, hue ='Surv_status' )

# %% [markdown]
# source: https://seaborn.pydata.org/generated/seaborn.pairplot.html
